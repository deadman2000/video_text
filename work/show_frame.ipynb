# %%
import cv2
from matplotlib import pyplot as plt
from extract import extract_text

import download

# %%
time_url = 'https://youtu.be/eziBU06QkoA?t=7401'

# %%
parts = time_url.split('?')
video_id = parts[0].split('/')[-1]
time = int(parts[1].split('=')[1])

# %% [raw]
# video_id='EvrZ5haT9rE'

# %% [raw]
# time=5180

# %%
path = download.download_video(video_id)

# %%
vidcap = cv2.VideoCapture(path)
fps = vidcap.get(cv2.CAP_PROP_FPS)
frame_num = time * fps
print('Frame:', frame_num)
# Out:
# Frame: 222030.0

# %%
vidcap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
success, image = vidcap.read()

plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
extract_text(image)
# Out:
# 'po TES :\nou bravely, stupidly grab the steaming, :\n4 fly—laden horse plop. Fortunately, it seems\n\nas\n\nto be holding together well as you place it\nin your pocket.\n\n'
