# %%
import cv2
from matplotlib import pyplot as plt
from random import randint

import download

# %%
time_url = 'https://youtu.be/XMPUmo6Bl1U?t=136'

# %%
parts = time_url.split('?')
video_id = parts[0].split('/')[-1]
time = int(parts[1].split('=')[1])

# %%
path = download.download_video(video_id)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XMPUmo6Bl1U
# [youtube] XMPUmo6Bl1U: Downloading webpage
# [youtube] XMPUmo6Bl1U: Downloading android player API JSON
# [info] XMPUmo6Bl1U: Downloading 1 format(s): 22
# [download] Destination: download\XMPUmo6Bl1U.mp4
# [download] 100% of  235.50MiB in 00:00:26 at 8.77MiB/s

# %%
vidcap = cv2.VideoCapture(path)
fps = vidcap.get(cv2.CAP_PROP_FPS)
frame_num = time * fps
print('Frame:', frame_num)
# Out:
# Frame: 4075.9240759240756

# %%
vidcap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
success, image = vidcap.read()

plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
