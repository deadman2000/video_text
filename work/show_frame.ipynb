# %%
import cv2
from matplotlib import pyplot as plt

import download

# %%
time_url = 'https://youtu.be/qYMoEwXUrhU?t=768'

# %%
parts = time_url.split('?')
video_id = parts[0].split('/')[-1]
time = int(parts[1].split('=')[1])

# %% [raw]
# video_id='EvrZ5haT9rE'
# time=9568

# %%
path = download.download_video(video_id)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qYMoEwXUrhU
# [youtube] qYMoEwXUrhU: Downloading webpage
# [youtube] qYMoEwXUrhU: Downloading ios player API JSON
# [youtube] qYMoEwXUrhU: Downloading android player API JSON
# [youtube] qYMoEwXUrhU: Downloading m3u8 information
# [info] qYMoEwXUrhU: Downloading 1 format(s): 22
# [download] Destination: download\qYMoEwXUrhU.mp4
# [download] 100% of  467.06MiB in 00:01:27 at 5.32MiB/s

# %%
vidcap = cv2.VideoCapture(path)
fps = vidcap.get(cv2.CAP_PROP_FPS)
frame_num = time * fps
print('Frame:', frame_num)
# Out:
# Frame: 23040.0

# %%
vidcap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
success, image = vidcap.read()

plt.axis("off")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
