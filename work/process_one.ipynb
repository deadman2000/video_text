# %%
import os

# %%
from matplotlib import pyplot as plt
import cv2
import pytesseract
import numpy as np

# %% [raw]
# os.environ['ELASTIC_URL'] = 'http://192.168.99.100:9200'

# %%
import download
from matching import find_match
from extract import unsharp_mask

# %%
# https://youtu.be/Oevq2aSOs0Mt=727
source = download.get_frame('Oevq2aSOs0M', 727)

plt.axis("off")
plt.imshow(cv2.cvtColor(source, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# [youtube] Oevq2aSOs0M: Downloading webpage
# [youtube] Oevq2aSOs0M: Downloading android player API JSON
# [info] Oevq2aSOs0M: Downloading 1 format(s): 18
# [download] download\Oevq2aSOs0M.mp4 has already been downloaded
# [download] 100% of 616.65MiB

# %%
source.shape
# Out:
# (360, 640, 3)

# %%
im = unsharp_mask(source)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)  # В оттенки серого
# h, w = im.shape
# scale = 320 // w
# im = cv2.resize(im, None, fx=scale, fy=scale)

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(pytesseract.image_to_string(source, config='--psm 3'))
# Out:
# ver mind, just pulling your le;
# Why don’t you take this desk
#
# right here, and we'll get you
# settled in.

# %%
print(pytesseract.image_to_string(source, config='--psm 4'))
# Out:
# ver mind, just pulling your le;
# Why don’t you take this desk
#
# right here, and we'll get you
# settled in.

# %%
text = pytesseract.image_to_string(unsharp_mask(source), config='--psm 3')
print(text)
# Out:
# Never mind, just pulling your leg.
# Why don’t you take this desk
#
# fight here, and we'll get you
# settled in,

# %% [raw]
# matches = find_match(text)
# for m in matches:
#     print("{score}\t{resource}:{line} \t {text}".format(**m))
