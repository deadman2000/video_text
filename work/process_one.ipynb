# %%
import os

# %%
from matplotlib import pyplot as plt
import cv2
import pytesseract
import numpy as np

# %%
import download
from extract import unsharp_mask

# %%
# https://youtu.be/Oevq2aSOs0Mt=727
source = download.get_frame('Oevq2aSOs0M', 721)

plt.axis("off")
plt.imshow(cv2.cvtColor(source, cv2.COLOR_BGR2RGB))
plt.show()

# %%
source.shape
# Out:
# (360, 640, 3)

# %%
print(pytesseract.image_to_string(source, config='--psm 3'))
# Out:
# @
#
# msi pardon me, id go
# ‘Ou {
# sue)
#
# " what di
# y
# a] ss ne
#
# ure he.
# s
# r

# %%
print(pytesseract.image_to_string(source, config='--psm 4'))

# %%
unsharp = unsharp_mask(source)
plt.axis("off")
plt.imshow(cv2.cvtColor(unsharp, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(pytesseract.image_to_string(unsharp, config='--psm 3'))

# %%
print(pytesseract.image_to_string(unsharp, config='--psm 4'))

# %%
im2 = unsharp_mask(cv2.resize(source, None, fx=2, fy=2))
