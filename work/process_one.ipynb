# %%
import os

# %%
from matplotlib import pyplot as plt
import cv2
import pytesseract
import numpy as np

# %%
os.environ['ELASTIC_URL'] = 'http://192.168.99.100:9200'

# %%
import download
from matching import find_match
from extract import unsharp_mask

# %%
# https://youtu.be/hKqI9gL30No?t=2608
source = download.get_frame('hKqI9gL30No', 2608)

plt.axis("off")
plt.imshow(cv2.cvtColor(source, cv2.COLOR_BGR2RGB))
plt.show()

# %%
im = unsharp_mask(source)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)  # В оттенки серого
# h, w = im.shape
# scale = 320 // w
# im = cv2.resize(im, None, fx=scale, fy=scale)

# %%
plt.axis("off")
plt.imshow(cv2.cvtColor(im, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(pytesseract.image_to_string(source, config='--psm 3'))
# Out:
# bee La pa pa lete) ats ean)
#
# Forgive my
# ferns tesa
# pele uan era
# Sein Costeae ted
# t tad
# Estes b ats t4
# and I need
# Ace Lba
# Coane

# %%
print(pytesseract.image_to_string(source, config='--psm 4'))
# Out:
# bee La pa pa lete) ats ean)
#
# Forgive my
# ferns tesa
# pele uan era
# Sein Costeae ted
# tad
# Estes b ats t4
# and I need
# Ace Lba
# Coane

# %%
text = pytesseract.image_to_string(unsharp_mask(source), config='--psm 3')
print(text)
# Out:
# bee aL pa pa leis ates so) eae)
#
# Forgive mu
# caution,
# eye n anaes
# beds ebe Me tt
# ates
# abe ae ea
# vale ieat=1=2)
# to be sure
# of you.

# %%
matches = find_match(text)
for m in matches:
    print("{score}\t{resource}:{line} \t {text}".format(**m))
# Out:
# 23.96366	1370.TEX:1 	 Forgive my caution, but the Sheriff has spies everywhere and I need to be sure of you.
# 19.851406	1169.TEX:16 	 Aye, after all that's happened, you can be sure the local monks and Sheriff's men would be keeping a sharp eye out for him.
# 19.241957	1530.TEX:119 	 I'll be ready, one-eye.
# 18.33126	1350.TEX:44 	 'ere now, don't you be layin' your filthy hands on me!
# 17.863272	1440.TEX:55 	 Aye?  So you're the man claiming to be one of us!
# 17.62005	1026.TEX:3 	 If you say so, I'm sure it must be.
# 15.592785	1190.TEX:21 	 Aye, a couple of men are keeping an eye upon the lad's parents.
# 15.5805855	1170.TEX:86 	 Aye, his caution failed him.
# 15.37378	1300.TEX:124 	 You don't look so lucky yourself, one-eye.
# 15.099021	1402.TEX:29 	 With but one eye, I beat all comers.
